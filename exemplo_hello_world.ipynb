# %% [markdown]
# # Exemplo Hello World
# Notebook inicial para testar o Jupyter no projeto.

# %%
print("Hello World1")
idade = 25
print("Minha idade e:", idade)
curso = "Formacao IA Generativa"
print("Estou fazendo o curso de:", curso)
